# %%
# !pip install pandas
# Out:
# ...
# [notice] A new release of pip is available: 25.3 -> 26.2.1
# [notice] To update, run: C:\Users\bmaru\AppData\Local\Python\pythoncore-3.14-64\python.exe -m pip install --upgrade pip

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import sys
print(sys.executable)
# Out:
# C:\Users\bmaru\AppData\Local\Python\pythoncore-3.14-64\python.exe

# %%
import pandas as pd

data = pd.read_excel(r"C:\Users\bmaru\Downloads\insurance.xlsx")

data
# Out:
#       age     sex   bmi  children smoker     region  expenses
# 0      19  female  27.9         0    yes  southwest  16884.92
# 1      18    male  33.8         1     no  southeast   1725.55
# 2      28    male  33.0         3     no  southeast   4449.46
# 3      33    male  22.7         0     no  northwest  21984.47
# 4      32    male  28.9         0     no  northwest   3866.86
# ...   ...     ...   ...       ...    ...        ...       ...
# 1333   50    male  31.0         3     no  northwest  10600.55
# 1334   18  female  31.9         0     no  northeast   2205.98
# 1335   18  female  36.9         0     no  southeast   1629.83
# 1336   21  female  25.8         0     no  southwest   2007.95
# 1337   61  female  29.1         0    yes  northwest  29141.36
#
# [1338 rows x 7 columns]

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   str
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   str
#  5   region    1338 non-null   str
#  6   expenses  1338 non-null   float64
# dtypes: float64(2), int64(2), str(3)
# memory usage: 73.3 KB

# %%
data.describe()
# Out:
#                age          bmi     children      expenses
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.665471     1.094918  13270.422414
# std      14.049960     6.098382     1.205493  12110.011240
# min      18.000000    16.000000     0.000000   1121.870000
# 25%      27.000000    26.300000     0.000000   4740.287500
# 50%      39.000000    30.400000     1.000000   9382.030000
# 75%      51.000000    34.700000     2.000000  16639.915000
# max      64.000000    53.100000     5.000000  63770.430000

# %%
import plotly.express as px
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

print("All libraries imported successfully!")
# Out:
# All libraries imported successfully!

# %%
import plotly.express as px
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline 
#to show chart as o/p not as popup

# %%
# changing some default settings to improve style and font size
sns.set_style("darkgrid")
matplotlib.rcParams["font.size"]= 14
matplotlib.rcParams["figure.figsize"]=(10,6)
matplotlib.rcParams["figure.facecolor"]="#00000000"

# %%
data.age.describe()
data
# Out:
#       age     sex   bmi  children smoker     region  expenses
# 0      19  female  27.9         0    yes  southwest  16884.92
# 1      18    male  33.8         1     no  southeast   1725.55
# 2      28    male  33.0         3     no  southeast   4449.46
# 3      33    male  22.7         0     no  northwest  21984.47
# 4      32    male  28.9         0     no  northwest   3866.86
# ...   ...     ...   ...       ...    ...        ...       ...
# 1333   50    male  31.0         3     no  northwest  10600.55
# 1334   18  female  31.9         0     no  northeast   2205.98
# 1335   18  female  36.9         0     no  southeast   1629.83
# 1336   21  female  25.8         0     no  southwest   2007.95
# 1337   61  female  29.1         0    yes  northwest  29141.36
#
# [1338 rows x 7 columns]

# %%
fig_age = px.histogram(data,x="age",marginal="box",nbins=47,title="distribution of Age") #(max_no_of_age - min_no_of_age)+1 = no_of_bins
fig_age.update_layout(bargap=0.1)
fig_age.show()

# %%
fig_bmi=px.histogram(data,x="bmi",marginal ="box",color_discrete_sequence=["red"],title ="Distribution of BodyMassIndex")
fig_bmi.update_layout(bargap=0.1)
fig_bmi.show()

# %%
fig_charges=px.histogram(data,x="expenses",marginal ="box",color="smoker",color_discrete_sequence=["green","gray",],title ="Annual medical  charges")
fig_charges.update_layout(bargap=0.1)
fig_charges.show()

# %%
fig_region=px.histogram(data,x="region",marginal ="box",color_discrete_sequence=["yellow"],title ="Distribution of region")
fig_region.update_layout(bargap=0.1)
fig_region.show()

# %%
fig_sex=px.histogram(data,x="sex",marginal ="box",color_discrete_sequence=["blue"],title ="Distribution of sex")
fig_sex.update_layout(bargap=0.01)
fig_sex.show()

# %%
data.smoker.value_counts()
# Out:
# smoker
# no     1064
# yes     274
# Name: count, dtype: int64

# %%
px.histogram(data,x="smoker",color ="sex",title="Smoker")

# %% [markdown]
# ## relationship between coloumn

# %%
age_ex = px.scatter(data, 
                 x="age", 
                 y="expenses", 
                 color="smoker", 
                 
                 hover_data=["sex"],
                 title="Age vs Charges")
age_ex.update_traces(marker=dict(size=5, opacity=0.8))
age_ex.show()

# %%
age_ex = px.scatter(data, 
                 x="bmi", 
                 y="expenses", 
                 color="smoker", 
                 opacity=0.8, 
                 hover_data=["sex"],
                 title="Age vs Charges")
age_ex.update_traces(marker_size=5)
age_ex.show()

# %%
children_ex = px.violin(data, 
                 x="children", 
                 y="expenses", 
                 color="smoker", 
                title="children vs Charges")

children_ex.show()

# %%
data.expenses.corr(data.age)
# Out:
# np.float64(0.29900819228508274)

# %%
data.expenses.corr(data.bmi)
# Out:
# np.float64(0.198576255018932)

# %%
data.expenses.corr(data.children)
#need numeric data to see corelation,if not numeric data then convert9
# Out:
# np.float64(0.06799823000532816)

# %%
smoker_value={"no": 0,"yes": 1}
smoker_numeric =data.smoker.map(smoker_value)
smoker_numeric
# Out:
# 0       1
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1333    0
# 1334    0
# 1335    0
# 1336    0
# 1337    1
# Name: smoker, Length: 1338, dtype: int64

# %%
sex_value={"Male": 0,"Female": 1}
sex_numeric =data.sex.map(sex_value)
sex=sex_numeric
data.expenses.corr(sex)
# Out:
# nan

# %%
data.expenses.corr(smoker_numeric)
# Out:
# np.float64(0.7872514298985536)

# %%
#data.corr()

# %%
non_smoker=data[data.smoker== "no"]
non_smoker
# Out:
#       age     sex   bmi  children smoker     region  expenses
# 1      18    male  33.8         1     no  southeast   1725.55
# 2      28    male  33.0         3     no  southeast   4449.46
# 3      33    male  22.7         0     no  northwest  21984.47
# 4      32    male  28.9         0     no  northwest   3866.86
# 5      31  female  25.7         0     no  southeast   3756.62
# ...   ...     ...   ...       ...    ...        ...       ...
# 1332   52  female  44.7         3     no  southwest  11411.69
# 1333   50    male  31.0         3     no  northwest  10600.55
# 1334   18  female  31.9         0     no  northeast   2205.98
# 1335   18  female  36.9         0     no  southeast   1629.83
# 1336   21  female  25.8         0     no  southwest   2007.95
#
# [1064 rows x 7 columns]

# %%
sns.scatterplot(data=non_smoker, x="age", y="expenses", alpha=0.7, s=15)

# Add title
plt.title("Age vs Charges")

# Add labels
plt.xlabel('Age')
plt.ylabel('Expenses')

# Show the plot
plt.show()

# %%
 def estimate_charges(age,w,b):
        return w*age+b

# %%
w=30
b=100
age = non_smoker.age
estimated_charges =estimate_charges(age,w,b)
estimated_charges
# Out:
# 1        640
# 2        940
# 3       1090
# 4       1060
# 5       1030
#         ...
# 1332    1660
# 1333    1600
# 1334     640
# 1335     640
# 1336     730
# Name: age, Length: 1064, dtype: int64

# %%
non_smoker.expenses
#both charges arer not maching means wrong prediction
# Out:
# 1        1725.55
# 2        4449.46
# 3       21984.47
# 4        3866.86
# 5        3756.62
#           ...
# 1332    11411.69
# 1333    10600.55
# 1334     2205.98
# 1335     1629.83
# 1336     2007.95
# Name: expenses, Length: 1064, dtype: float64

# %%
## to check how efficient our model is :
target =non_smoker.expenses
plt.plot(age,estimated_charges ,"r",alpha =0.9);
plt.scatter(data=non_smoker, x="age", y="expenses", alpha=0.7, s=15);
plt.xlabel("age");
plt.ylabel("expenses")
plt.legend(["estimate","Actual"]);

# %%
# as line not fitted well so lets try with diffrent w and b
def try_parameter(w,b):
    ages= non_smoker.age
    target=non_smoker.expenses
    estimated_charges =estimate_charges(age,w,b)
    plt.plot(age,estimated_charges ,"r",alpha =0.9);
    plt.scatter(data=non_smoker, x="age", y="expenses", alpha=0.7, s=15);
    plt.xlabel("age");
    plt.ylabel("expenses")
    plt.legend(["estimate","Actual"]);

# %%
try_parameter(200,200)

# %%
# to get best fit line need to find diffrence b/t actual expenses and predicted expense
target = non_smoker.expenses
target
# Out:
# 1        1725.55
# 2        4449.46
# 3       21984.47
# 4        3866.86
# 5        3756.62
#           ...
# 1332    11411.69
# 1333    10600.55
# 1334     2205.98
# 1335     1629.83
# 1336     2007.95
# Name: expenses, Length: 1064, dtype: float64

# %%
prediction =estimated_charges
prediction
# Out:
# 1        640
# 2        940
# 3       1090
# 4       1060
# 5       1030
#         ...
# 1332    1660
# 1333    1600
# 1334     640
# 1335     640
# 1336     730
# Name: age, Length: 1064, dtype: int64

# %%
import numpy as np

# %%
def rmse (target,prediction):
    return np.sqrt(np.mean(np.square(target- prediction)))

# %%
w=50
b=100

# %%
try_parameter(w,b)

# %%
targets=non_smoker["expenses"]
predicted =estimate_charges(non_smoker.age,w,b)

# %%
rmse(targets,predicted)
# Out:
# np.float64(8461.949627404152)

# %%
def try_parameter(w,b):
    ages= non_smoker.age
    target=non_smoker.expenses
    estimated_charges =estimate_charges(age,w,b)
    plt.plot(age,estimated_charges ,"r",alpha =0.9);
    plt.scatter(data=non_smoker, x="age", y="expenses", alpha=0.7, s=15);
    plt.xlabel("age");
    plt.ylabel("expenses")
    plt.legend(["estimate","Actual"]);
    
    loss= rmse(target,estimated_charges)
    print("RMSE LOSS :", loss)

# %%
try_parameter(350,-4000)
#loss should be minimum
# Out:
# RMSE LOSS : 4991.993634408342

# %%
pip install scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.2.1
# [notice] To update, run: C:\Users\bmaru\AppData\Local\Python\pythoncore-3.14-64\python.exe -m pip install --upgrade pip

# %% [markdown]
# from sklearn.linear_model import Linearregressionfrom sklearn.linear_model import Linearregression

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()  # creat new model object
help(model.fit)
inputs =non_smoker[["age"]]
targets=non_smoker.expenses
print("input.shape :",inputs.shape)
print("target.shape :",targets.shape)
# Out:
# Help on method fit in module sklearn.linear_model._base:
#
# fit(X, y, sample_weight=None) method of sklearn.linear_model._base.LinearRegression instance
#     Fit linear model.
#
#     Parameters
#     ----------
#     X : {array-like, sparse matrix} of shape (n_samples, n_features)
#         Training data.
#
#     y : array-like of shape (n_samples,) or (n_samples, n_targets)
#         Target values. Will be cast to X's dtype if necessary.
#
#     sample_weight : array-like of shape (n_samples,), default=None
#         Individual weights for each sample.
#
#         .. versionadded:: 0.17
#            parameter *sample_weight* support to LinearRegression.
#
#     Returns
#     -------
#     self : object
#         Fitted Estimator.
#
# input.shape : (1064, 1)
# target.shape : (1064,)

# %%
model.fit(inputs,targets)
# Out:
# LinearRegression()

# %%
predictions =model.predict(inputs)
predictions
# Out:
# array([2719.05994381, 5391.54911046, 6727.79369378, ..., 2719.05994381,
#        2719.05994381, 3520.8066938 ], shape=(1064,))

# %%
rmse(targets,predictions)
# Out:
# np.float64(4662.505642227754)

# %%
# w
print("coefcient : ",model.coef_)


#b
print(" intercept  :",model.intercept_)
# Out:
# coefcient :  [267.24891666]
#  intercept  : -2091.420556151412

# %%
try_parameter(model.coef_,model.intercept_)
# Out:
# RMSE LOSS : 4662.505642227754
